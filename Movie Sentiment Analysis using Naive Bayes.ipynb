# %% [markdown]
# # __Movie Sentiment Analysis using Naive Bayes__

# %%
import pandas as pd
import numpy as np
import re
import contractions
import nltk
import contractions
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import text_preprocessing as tp
import utils
import spacy
import seaborn as sb

from nltk.corpus import stopwords
from nltk.corpus import words
from nltk.stem import WordNetLemmatizer
from flashtext import KeywordProcessor
from wordcloud import WordCloud
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV
from collections import Counter
from sklearn.metrics import confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Importing Dataset for Movie Metadata
#
# Use the IMDB dataset containing information about movies. Two different data sources will be utilized in the process of traning the model.
#
# __a. Data Source:__ https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset/

# %%
# Open file containing movie metadata
movies_metadata_df = pd.read_csv("./dataset/movies_metadata.csv")
movies_metadata_df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    10/30/1995
# 1  When siblings Judy and Peter discover an encha...  ...    12/15/1995
# 2  A family wedding reignites the ancient feud be...  ...    12/22/1995
# 3  Cheated on, mistreated and stepped on, the wom...  ...    12/22/1995
# 4  Just when George Banks has recovered from his ...  ...     2/10/1995
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
# Open file containing the movie credits, i.e. casts and crews
movies_credits_df = pd.read_csv("./dataset/credits.csv")
movies_credits_df.head(5)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
# Combine the dataframes of movie metadata and credits
movies_metadata_df = pd.merge(movies_metadata_df, movies_credits_df, on=["id"], how="left")
movies_metadata_df.head(5)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  runtime  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...     81.0
# 1  When siblings Judy and Peter discover an encha...  ...    104.0
# 2  A family wedding reignites the ancient feud be...  ...    101.0
# 3  Cheated on, mistreated and stepped on, the wom...  ...    127.0
# 4  Just when George Banks has recovered from his ...  ...    106.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average vote_count  \
# 0                    Toy Story  False           7.7     5415.0
# 1                      Jumanji  False           6.9     2413.0
# 2             Grumpier Old Men  False           6.5       92.0
# 3            Waiting to Exhale  False           6.1       34.0
# 4  Father of the Bride Part II  False           5.7      173.0
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...
#
# [5 rows x 26 columns]

# %%
# List all the columns in movie metadata's dataframe
movies_metadata_df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew'],
#       dtype='object')

# %%
# Drop columns that are not relevant
del_columns = ['belongs_to_collection', 'homepage', 'id', 'original_language', 'original_title', 'popularity', 'poster_path', 'adult',
               'overview', 'tagline', 'production_countries', 'spoken_languages', 'status', 'video', 'vote_average', 'vote_count']
movies_metadata_df = movies_metadata_df.drop(del_columns, axis=1)

# Remove 'tt' appended on the IMDB ID
movies_metadata_df['imdb_id'] = movies_metadata_df['imdb_id'].apply(lambda x : x[2:] if isinstance(x, str) and "tt" in x else x)

movies_metadata_df.head(5)
# Out:
#      budget                                             genres  imdb_id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  0114709
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  0113497
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  0113228
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  0114885
# 4         0                     [{'id': 35, 'name': 'Comedy'}]  0113041
#
#                                 production_companies release_date  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]   10/30/1995
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...   12/15/1995
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...   12/22/1995
# 3  [{'name': 'Twentieth Century Fox Film Corporat...   12/22/1995
# 4  [{'name': 'Sandollar Productions', 'id': 5842}...    2/10/1995
#
#        revenue  runtime                        title  \
# 0  373554033.0     81.0                    Toy Story
# 1  262797249.0    104.0                      Jumanji
# 2          0.0    101.0             Grumpier Old Men
# 3   81452156.0    127.0            Waiting to Exhale
# 4   76578911.0    106.0  Father of the Bride Part II
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...

# %% [markdown]
# __b. Data Source:__ https://www.kaggle.com/datasets/raynardj/imdb-vision-and-nlp/data

# %%
# Open another file containing the movie metadata
movies_df = pd.read_csv("./dataset/movies.csv")
movies_df.head(5)
# Out:
#    imdbId                           Imdb Link                Title  \
# 0  114709  http://www.imdb.com/title/tt114709     Toy Story (1995)
# 1  113497  http://www.imdb.com/title/tt113497       Jumanji (1995)
# 2  113277  http://www.imdb.com/title/tt113277          Heat (1995)
# 3  114319  http://www.imdb.com/title/tt114319       Sabrina (1995)
# 4  114576  http://www.imdb.com/title/tt114576  Sudden Death (1995)
#
#    IMDB Score                       Genre    local_image_path
# 0         8.3  Animation;Adventure;Comedy  images/114709_.jpg
# 1         6.9     Action;Adventure;Family  images/113497_.jpg
# 2         8.2          Action;Crime;Drama  images/113277_.jpg
# 3         6.3                Comedy;Drama  images/114319_.jpg
# 4         5.7       Action;Crime;Thriller  images/114576_.jpg

# %%
# Rename the column names of movies info by removing the spaces and converting to lower case
movies_df = movies_df.rename(columns={"imdbId" : "imdb_id", "Imdb Link" : "imbd_link", "Title" : "movie", "IMDB Score" : "imdb_score", "Genre" : "genre"})
print(movies_df.columns)
# Out:
# Index(['imdb_id', 'imbd_link', 'movie', 'imdb_score', 'genre',
#        'local_image_path'],
#       dtype='object')

# %%
# Drop columns that are not relevant
del_columns = ['imbd_link', 'imdb_score', 'local_image_path']

movies_df = movies_df.drop(columns=del_columns, axis=1)
movies_df.head(5)
# Out:
#    imdb_id                movie                       genre
# 0   114709     Toy Story (1995)  Animation;Adventure;Comedy
# 1   113497       Jumanji (1995)     Action;Adventure;Family
# 2   113277          Heat (1995)          Action;Crime;Drama
# 3   114319       Sabrina (1995)                Comedy;Drama
# 4   114576  Sudden Death (1995)       Action;Crime;Thriller

# %%
# Merge two different datasets for movies metadata

movies_metadata_df['imdb_id'] = movies_metadata_df['imdb_id'].fillna(0) # fixed errors on NaN values when converting to int data type
movies_metadata_df['imdb_id'] = movies_metadata_df['imdb_id'].astype(int)

movies_metadata_df = pd.merge(movies_metadata_df, movies_df, on=["imdb_id"], how="right")
movies_metadata_df.head(5)
# Out:
#        budget                                             genres  imdb_id  \
# 0  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   114709
# 1  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   113497
# 2  60000000.0  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...   113277
# 3  58000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...   114319
# 4  35000000.0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...   114576
#
#                                 production_companies release_date  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]   10/30/1995
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...   12/15/1995
# 2  [{'name': 'Regency Enterprises', 'id': 508}, {...   12/15/1995
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...   12/15/1995
# 4  [{'name': 'Universal Pictures', 'id': 33}, {'n...   12/22/1995
#
#        revenue  runtime         title  \
# 0  373554033.0     81.0     Toy Story
# 1  262797249.0    104.0       Jumanji
# 2  187436818.0    170.0          Heat
# 3          0.0    127.0       Sabrina
# 4   64350171.0    106.0  Sudden Death
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 3  [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew                movie  \
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     Toy Story (1995)
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...       Jumanji (1995)
# 2  [{'credit_id': '52fe4292c3a36847f802916d', 'de...          Heat (1995)
# 3  [{'credit_id': '52fe44959251416c75039da9', 'de...       Sabrina (1995)
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...  Sudden Death (1995)
#
#                         genre
# 0  Animation;Adventure;Comedy
# 1     Action;Adventure;Family
# 2          Action;Crime;Drama
# 3                Comedy;Drama
# 4       Action;Crime;Thriller

# %% [markdown]
# ## Importing Dataset for Movie Reviews
#
# Use the IMDB dataset for movie reviews.
#
# __Data Source:__ https://www.kaggle.com/datasets/raynardj/imdb-vision-and-nlp/data

# %%
# Open the file containing the movie reviews
reviews_df = pd.read_csv("./dataset/reviews.csv")
reviews_df.head(5)
# Out:
#    review_id             reviewer                             movie  rating  \
# 0  rw0213367    SUPERNOVA HEIGHTS  A Nightmare on Elm Street (1984)     8.0
# 1  rw0213369  kibler@adelphia.net  A Nightmare on Elm Street (1984)     NaN
# 2  rw0213371            matthew87  A Nightmare on Elm Street (1984)     NaN
# 3  rw0213375         rossrobinson  A Nightmare on Elm Street (1984)    10.0
# 4  rw0213376             Andres24  A Nightmare on Elm Street (1984)     9.0
#
#                           review_summary        review_date  spoiler_tag  \
# 0  A Classic of the horror films History     27 August 2003            0
# 1  Better than your average horror movie   1 September 2003            0
# 2                     good slasher flick   1 September 2003            0
# 3           A nightmare on elm st part 1  27 September 2003            0
# 4                        Highway to hell     3 October 2003            0
#
#                                        review_detail     helpful  \
# 0  This is the beginning of a great horror film s...  ['0', '0']
# 1  Nightmare on Elm Street, A (1984) John Saxon, ...  ['0', '0']
# 2  the best freddy film period,1 because the horr...  ['0', '0']
# 3  I remember seeing a nightmare on elm street pa...  ['0', '2']
# 4  It's a nightmare.  If Nancy falls asleep, they...  ['1', '1']
#
#    roberta_sentiment
# 0           Positive
# 1           Negative
# 2  Strongly Positive
# 3           Negative
# 4           Positive

# %%
# Merge the movie metadata (from the same kaggle source) and reviews
movie_reviews_df = pd.merge(movies_df, reviews_df, on=["movie"], how="inner")
movie_reviews_df.head(5)
# Out:
#    imdb_id             movie                       genre  review_id  \
# 0   114709  Toy Story (1995)  Animation;Adventure;Comedy  rw1223346
# 1   114709  Toy Story (1995)  Animation;Adventure;Comedy  rw3110243
# 2   114709  Toy Story (1995)  Animation;Adventure;Comedy  rw3109622
# 3   114709  Toy Story (1995)  Animation;Adventure;Comedy  rw3124846
# 4   114709  Toy Story (1995)  Animation;Adventure;Comedy  rw3635799
#
#       reviewer  rating                          review_summary  \
# 0     KUAlum26    10.0            Can it be ten years already?
# 1       MUFCOK    10.0                   A childhood favourite
# 2  Rainey-Dawn     6.0             Not As Good As I Was Hoping
# 3    byson5186     9.0  Why The First Toy Story Is My Favorite
# 4     snperera     9.0             A classic friendship story!
#
#         review_date  spoiler_tag  \
# 0  23 November 2005            0
# 1   24 October 2014            0
# 2   23 October 2014            0
# 3  15 November 2014            0
# 4   8 February 2017            0
#
#                                        review_detail     helpful  \
# 0  PIXAR animation was but an experimental animat...  ['1', '1']
# 1  Toy Story is one of those movies which holds a...  ['1', '2']
# 2  This is another one of my "I should like this ...  ['2', '8']
# 3  So far they have come out with 3 Toy Story mov...  ['0', '1']
# 4  Wow, well what can I say! This is a favorite o...  ['0', '1']
#
#    roberta_sentiment
# 0           Positive
# 1  Strongly Positive
# 2            Neutral
# 3           Positive
# 4  Strongly Positive

# %%
# Drop columns that are not relevant, including the movie and genre. IMDB ID can be used to associate 
# review records with movie metadata
del_columns = ['movie', 'genre', 'review_id', 'reviewer', 'spoiler_tag', 'helpful', 'rating']

movie_reviews_df = movie_reviews_df.drop(columns=del_columns, axis=1)
movie_reviews_df.head(5)
# Out:
#    imdb_id                          review_summary       review_date  \
# 0   114709            Can it be ten years already?  23 November 2005
# 1   114709                   A childhood favourite   24 October 2014
# 2   114709             Not As Good As I Was Hoping   23 October 2014
# 3   114709  Why The First Toy Story Is My Favorite  15 November 2014
# 4   114709             A classic friendship story!   8 February 2017
#
#                                        review_detail  roberta_sentiment
# 0  PIXAR animation was but an experimental animat...           Positive
# 1  Toy Story is one of those movies which holds a...  Strongly Positive
# 2  This is another one of my "I should like this ...            Neutral
# 3  So far they have come out with 3 Toy Story mov...           Positive
# 4  Wow, well what can I say! This is a favorite o...  Strongly Positive

# %% [markdown]
# ## Exploratory Data Analysis
#
# Check and resolve duplicate records

# %%
# Drop duplicate records in movies metadata
print(f"Record count before removing duplicates => {movies_metadata_df.shape[0]}")
movies_metadata_df.drop_duplicates(inplace=True)
print(f"Record count after removing duplicates  => {movies_metadata_df.shape[0]}")
# Out:
# Record count before removing duplicates => 4174
# Record count after removing duplicates  => 4071

# %%
# Drop duplicate records in movies reviews
print(f"Record count before removing duplicates => {movie_reviews_df.shape[0]}")
movie_reviews_df.drop_duplicates(inplace=True)
print(f"Record count after removing duplicates  => {movie_reviews_df.shape[0]}")
# Out:
# Record count before removing duplicates => 544638
# Record count after removing duplicates  => 530424

# %% [markdown]
# Check and resolve missing values for `movie metadata`

# %%
# Check for missing values in movies metadata
movies_metadata_df.isna().sum()
# Out:
# budget                  3
# genres                  3
# imdb_id                 0
# production_companies    3
# release_date            3
# revenue                 3
# runtime                 3
# title                   3
# cast                    3
# crew                    3
# movie                   0
# genre                   0
# dtype: int64

# %%
# List of movies with missing information
movies_metadata_df[movies_metadata_df['title'].isna()]
# Out:
#       budget genres  imdb_id production_companies release_date  revenue  \
# 2780     NaN    NaN   462322                  NaN          NaN      NaN
# 3521     NaN    NaN   448694                  NaN          NaN      NaN
# 3793     NaN    NaN  1937390                  NaN          NaN      NaN
#
#       runtime title cast crew                        movie  \
# 2780      NaN   NaN  NaN  NaN            Grindhouse (2007)
# 3521      NaN   NaN  NaN  NaN         Puss in Boots (2011)
# 3793      NaN   NaN  NaN  NaN  Nymphomaniac: Vol. I (2013)
#
#                            genre
# 2780      Action;Horror;Thriller
# 3521  Animation;Action;Adventure
# 3793                       Drama

# %%
# Drop all movies with missing information
movies_metadata_df.dropna(inplace=True, axis=0)
movies_metadata_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4068 entries, 0 to 4173
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4068 non-null   float64
#  1   genres                4068 non-null   object
#  2   imdb_id               4068 non-null   int64
#  3   production_companies  4068 non-null   object
#  4   release_date          4068 non-null   object
#  5   revenue               4068 non-null   float64
#  6   runtime               4068 non-null   float64
#  7   title                 4068 non-null   object
#  8   cast                  4068 non-null   object
#  9   crew                  4068 non-null   object
#  10  movie                 4068 non-null   object
#  11  genre                 4068 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 413.2+ KB

# %% [markdown]
# Check and resolve missing values for `movie reviews`

# %%
# Check for missing values in movies reviews
movie_reviews_df.isna().sum()
# Out:
# imdb_id              0
# review_summary       1
# review_date          0
# review_detail        0
# roberta_sentiment    0
# dtype: int64

# %%
# Replace all missing values in review summary and detail with a blank
movie_reviews_df[['review_summary', 'review_detail']] = movie_reviews_df[['review_summary', 'review_detail']].fillna('')
movie_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530424 entries, 0 to 544637
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   imdb_id            530424 non-null  int64
#  1   review_summary     530424 non-null  object
#  2   review_date        530424 non-null  object
#  3   review_detail      530424 non-null  object
#  4   roberta_sentiment  530424 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 24.3+ MB

# %% [markdown]
# #### __Data Wrangling and Visualizations__:
#
# Conduct data wrangling on `movie metadata` to transform and structure data into a desired format

# %%
# Separate movie release year from the title
pattern_year = r'\((\d{4})\)$'
movies_metadata_df['release_year'] = movies_metadata_df['movie'].str.extract(pattern_year).astype(int)
movies_metadata_df['movie'] = movies_metadata_df['movie'].str.replace(pattern_year, '', regex=True).str.strip()
movies_metadata_df[['movie', 'release_year']].head(5)

# Drop columns containing duplicate movie information
dup_columns = ['genres', 'release_date', 'title']
movies_metadata_df = movies_metadata_df.drop(columns=dup_columns, axis=1)

# Rearrange the order of columns
desired_order = ['imdb_id', 'movie', 'release_year', 'genre', 'runtime', 'budget', 'revenue', 'production_companies', 'cast', 'crew']
movies_metadata_df = movies_metadata_df[desired_order]

movies_metadata_df.head(5)
# Out:
#    imdb_id         movie  release_year                       genre  runtime  \
# 0   114709     Toy Story          1995  Animation;Adventure;Comedy     81.0
# 1   113497       Jumanji          1995     Action;Adventure;Family    104.0
# 2   113277          Heat          1995          Action;Crime;Drama    170.0
# 3   114319       Sabrina          1995                Comedy;Drama    127.0
# 4   114576  Sudden Death          1995       Action;Crime;Thriller    106.0
#
#        budget      revenue                               production_companies  \
# 0  30000000.0  373554033.0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  65000000.0  262797249.0  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  60000000.0  187436818.0  [{'name': 'Regency Enterprises', 'id': 508}, {...
# 3  58000000.0          0.0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  35000000.0   64350171.0  [{'name': 'Universal Pictures', 'id': 33}, {'n...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 3  [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 3  [{'credit_id': '52fe44959251416c75039da9', 'de...
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...

# %%
# Convert genre into list data type
movies_metadata_df['genre'] = movies_metadata_df['genre'].apply(lambda x : x.split(";"))

# Convert to a list of production companies
movies_metadata_df['production_companies'] = movies_metadata_df['production_companies'].apply(lambda x : utils.convert_str_to_dict(x, ['name']))
movies_metadata_df['production_companies'] = movies_metadata_df['production_companies'].apply(lambda list_of_dicts : [value for d in list_of_dicts for value in d.values()])

# TODO: Need to fix the issue on cast and crew with names containing single quotation
# movies_metadata_df['cast'] = movies_metadata_df['cast'].apply(lambda x : utils.convert_str_to_dict(x, ['character', 'name']))

movies_metadata_df[['genre', 'production_companies', 'cast', 'crew']].head(5)
# Out:
#                             genre  \
# 0  [Animation, Adventure, Comedy]
# 1     [Action, Adventure, Family]
# 2          [Action, Crime, Drama]
# 3                 [Comedy, Drama]
# 4       [Action, Crime, Thriller]
#
#                                 production_companies  \
# 0                          [Pixar Animation Studios]
# 1  [TriStar Pictures, Teitler Film, Interscope Co...
# 2  [Regency Enterprises, Forward Pass, Warner Bros.]
# 3  [Paramount Pictures, Scott Rudin Productions, ...
# 4  [Universal Pictures, Imperial Entertainment, S...
#
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 25, 'character': 'Lt. Vincent Han...
# 3  [{'cast_id': 1, 'character': 'Linus Larrabee',...
# 4  [{'cast_id': 1, 'character': 'Darren Francis T...
#
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe4292c3a36847f802916d', 'de...
# 3  [{'credit_id': '52fe44959251416c75039da9', 'de...
# 4  [{'credit_id': '52fe44dbc3a36847f80ae0f1', 'de...

# %% [markdown]
# Conduct data wrangling on `movie review` to transform and structure data into a desired format

# %%
# Get only the year the review was created
movie_reviews_df['review_year'] = pd.to_datetime(movie_reviews_df['review_date']).dt.year
movie_reviews_df = movie_reviews_df.drop(columns=['review_date'], axis=1)

movie_reviews_df.head(5)
# Out:
#    imdb_id                          review_summary  \
# 0   114709            Can it be ten years already?
# 1   114709                   A childhood favourite
# 2   114709             Not As Good As I Was Hoping
# 3   114709  Why The First Toy Story Is My Favorite
# 4   114709             A classic friendship story!
#
#                                        review_detail  roberta_sentiment  \
# 0  PIXAR animation was but an experimental animat...           Positive
# 1  Toy Story is one of those movies which holds a...  Strongly Positive
# 2  This is another one of my "I should like this ...            Neutral
# 3  So far they have come out with 3 Toy Story mov...           Positive
# 4  Wow, well what can I say! This is a favorite o...  Strongly Positive
#
#    review_year
# 0         2005
# 1         2014
# 2         2014
# 3         2014
# 4         2017

# %% [markdown]
# Perform additional analysis of the data and create visual representations to gain a better understanding of the movie metadata and reviews. This information provides insights on trends and patterns in the movie data, which might be important especially on the reports that will be provided to the client.

# %%
# Show statistical summary of movie metadata and reviews
pd.merge(movies_metadata_df, movie_reviews_df, on=["imdb_id"], how="inner").describe()
# Out:
#             imdb_id   release_year        runtime        budget       revenue  \
# count  5.303050e+05  530305.000000  530305.000000  5.303050e+05  5.303050e+05
# mean   5.588570e+05    1995.732624     112.396840  4.183635e+07  1.533788e+08
# std    7.610144e+05      18.321590      22.414053  5.311250e+07  2.433054e+08
# min    4.170000e+02    1902.000000       0.000000  0.000000e+00  0.000000e+00
# 25%    9.595600e+04    1988.000000      97.000000  3.500000e+06  1.029760e+07
# 50%    2.537540e+05    2002.000000     109.000000  2.100000e+07  6.127945e+07
# 75%    4.983800e+05    2008.000000     124.000000  6.000000e+07  1.864389e+08
# max    5.247022e+06    2017.000000     254.000000  3.800000e+08  2.787965e+09
#
#          review_year
# count  530305.000000
# mean     2009.918496
# std         6.258123
# min      1998.000000
# 25%      2005.000000
# 50%      2010.000000
# 75%      2015.000000
# max      2021.000000

# %%
# Get the frequency of values in the 'roberta_sentiment' column
sentiment_counts = movie_reviews_df['roberta_sentiment'].value_counts()
sentiment_counts.plot(kind='bar', edgecolor='black')

plt.xlabel('Sentiments')
plt.ylabel('Frequency')
plt.title('Frequency of Movie Reviews Sentiments')
plt.show()

# %% [markdown]
# #### __For Text Pre-processing__:
#
# __The movie summary and reviews undergo the following steps during the initial data pre-processing stage__
# - Remove non-grammatical text like emails and URLs
# - Replace non-ascii characters (some Python libraries are only limited to ascii characters like KeywordProcessor)
# - Replace emojis with English word/s
# - Handle contractions
# - Handle slang words

# %%
emoji_dict = tp.get_emojis()
slang_word_dict = tp.get_slang_words(webscraped=False)

def initial_text_preprocessing(text):
    try:
        # Remove non-grammatical text
        text = tp.remove_email_address(text)
        text = tp.remove_hyperlink(text)

        # Replace non-ascii characters as there are Python libraries limiting this feature
        text = tp.replace_nonascii_characters(text)

        # Replace emojis with English word/s
        text = emoji_dict.replace_keywords(text)

        # Handle contractions
        text = contractions.fix(text)

        # Replace slang words
        text = slang_word_dict.replace_keywords(text)

    except Exception as err:
        print(f"ERROR: {err}")
        print(f"Input Text: {text}")

    return text


movie_reviews_df[['cleaned_review_summary', 'cleaned_review_detail']] = movie_reviews_df[['review_summary', 'review_detail']].applymap(initial_text_preprocessing)

# Display the comparison between the top 5 original review summaries and their cleaned versions
for i in range(5):
    print("Original Review Summary:")
    print(movie_reviews_df['review_summary'][i])
    print("\nCleaned Review Summary:")
    print(movie_reviews_df['cleaned_review_summary'][i])
    print("="*100)

# Display the comparison between the top 5 original review details and their cleaned versions
for i in range(5):
    print("Original Review Details:")
    print(movie_reviews_df['review_detail'][i])
    print("\nCleaned Review Details:")
    print(movie_reviews_df['cleaned_review_detail'][i])
    print("="*100)
# Out:
# Original Review Summary:
# Can it be ten years already?
#
# Cleaned Review Summary:
# Can it be ten years already?
# ====================================================================================================
# Original Review Summary:
# A childhood favourite
#
# Cleaned Review Summary:
# A childhood favourite
# ====================================================================================================
# Original Review Summary:
# Not As Good As I Was Hoping
#
# Cleaned Review Summary:
# Not As Good As I Was Hoping
# ====================================================================================================
# Original Review Summary:
# Why The First Toy Story Is My Favorite
#
# Cleaned Review Summary:
# Why The First Toy Story Is My Favorite
# ====================================================================================================
# Original Review Summary:
# A classic friendship story!
#
# Cleaned Review Summary:
# A classic friendship story!
# ====================================================================================================
# Original Review Details:
# PIXAR animation was but an experimental animation company that had a track record of short film contributions to film festivals when Disney invested in and ultimately released their first project,Toy Story. I figured Disney probably had a good feeling about this one,but I'm not sure they anticipated the kind of groundbreaking swell of animation this would shepherd in.The concept is a fitfully simple and cute one: when kids are away,their toys take on personalities and lives of their own,plotting,planning,bickering,reacting,flirting,etc. In this particular den of toys, a Cowboy Woody doll(voiced by Tom Hanks) is the leader,flanked by a Slinky dog(Jim Varney),green toy soldiers(aptly casted R.Lee Ermey as their platoon leader),a Mr.Potato head(Don Rickles), a Piggy bank(John Ratzenberger,forever Cliff Claven from "Cheers") and a Bo Peep doll(Annie Potts). Into the mix is a new,electronic Buzz Lightyear action figure(Tim Allen,who probably does the best voice acting of the bunch here),who almost instantly wows the locals and stirs jealousy from Woody.With music from Randy Newmann--a personal fave of mine--this movie's colors,attention to detail and wry humor make it easily adaptable to kids and adults alike. CAn it really be ten years since this film broke new ground on animation? How time flies in the wake of stuff like "Shrek" and "FInding Nemo"!
#
# Cleaned Review Details:
# PIXAR animation was but an experimental animation company that had a track record of short film contributions to film festivals when Disney invested in and ultimately released their first project,Toy Story. I figured Disney probably had a good feeling about this one,but I am not sure they anticipated the kind of groundbreaking swell of animation this would shepherd in.The concept is a fitfully simple and cute one: when kids are away,their toys take on personalities and lives of their own,plotting,planning,bickering,reacting,flirting,etc. In this particular den of toys, a Cowboy Woody doll(voiced by Tom Hanks) is the leader,flanked by a Slinky dog(Jim Varney),green toy soldiers(aptly casted R.Lee Ermey as their platoon leader),a Mr.Potato head(Don Rickles), a Piggy bank(John Ratzenberger,forever Cliff Claven from "Cheers") and a Bo Peep doll(Annie Potts). Into the mix is a new,electronic Buzz Lightyear action figure(Tim Allen,who probably does the best voice acting of the bunch here),who almost instantly wows the locals and stirs jealousy from Woody.With music from Randy Newmann--a personal fave of mine--this movie's colors,attention to detail and wry humor make it easily adaptable to kids and adults alike. CAn it really be ten years since this film broke new ground on animation? How time flies in the wake of stuff like "Shrek" and "FInding Nemo"!
# ====================================================================================================
# Original Review Details:
# Toy Story is one of those movies which holds a lot of good childhood memories for me. I first saw it in the cinema as a child, it was then worn out on VHS tape. Played to death on DVD & is now owned on special edition Blu Ray. It is by far, one of my favourite ever movies. Everything about this movie is perfect. It is a subject which is relateable to every single person who has ever watched this film; that our toys came to life when weren't there. In Toy Story the toys don't just simply come to life, they have their own world, their own relationships, their own problems and conflicts. But above all else they have friendship, loyalty & a special togetherness. The story begins with the Toys in Andy's bedroom. It is the day of Andy's birthday party and the toys gather round anxious awaiting the news as to whether a new toy has been given as a birthday present, and if it is to be Andy's new 'favourite toy'. The toy that is handed over as a present is the brand spanking new, space ranger, Buzz Lightyear. All the other toys are all in awe of him, all toys that is, expect for Woody, Andy's current favourite Toy. Woody feels threatened by Buzz and has no patience when Buzz genuinely believes that he is a real space ranger & not a toy. The story progresses sending the toys on an adventure which is like no other seen before!The casting for Toy Story is simply perfect. Tom Hanks & Tim Allen put in fantastic performances as Woody & Buzz. The relationship they create is so believable and they develop fantastic chemistry throughout the film. The best thing about Toy Story is the way it manages to involve you in the film. It makes you feel all of the toys emotions & really makes you feel for them. But at the end of the day they are just toys! We shouldn't get that involved yet somehow we do! Toy Story has many hidden meanings and gestures which really drive home the message of friendship and love. They are not cheesy, they are touching and realistic. This is what Disney do so well, they make children's films but whilst doing so they create them so they can be related to by adults. The animation is also on the money, this movie is almost 20 years old but looks as good today on Blu Ray as any other animation. Toy Story also has one brilliant soundtrack with several songs which will stay with you long after you have watched it. Overall I cannot recommend this film enough and I would recommend anybody to go and watch it, no matter what your age.A timeless classic. 10/10
#
# Cleaned Review Details:
# Toy Story is one of those movies which holds a lot of good childhood memories for me. I first saw it in the cinema as a child, it was then worn out on VHS tape. Played to death on DVD & is now owned on special edition Blu Ray. It is by far, one of my favourite ever movies. Everything about this movie is perfect. It is a subject which is relateable to every single person who has ever watched this film; that our toys came to life when were not there. In Toy Story the toys do not just simply come to life, they have their own world, their own relationships, their own problems and conflicts. But above all else they have friendship, loyalty & a special togetherness. The story begins with the Toys in Andy's bedroom. It is the day of Andy's birthday party and the toys gather round anxious awaiting the news as to whether a new toy has been given as a birthday present, and if it is to be Andy's new 'favourite toy'. The toy that is handed over as a present is the brand spanking new, space ranger, Buzz Lightyear. All the other toys are all in awe of him, all toys that is, expect for Woody, Andy's current favourite Toy. Woody feels threatened by Buzz and has no patience when Buzz genuinely believes that he is a real space ranger & not a toy. The story progresses sending the toys on an adventure which is like no other seen before!The casting for Toy Story is simply perfect. Tom Hanks & Tim Allen put in fantastic performances as Woody & Buzz. The relationship they create is so believable and they develop fantastic chemistry throughout the film. The best thing about Toy Story is the way it manages to involve you in the film. It makes you feel all of the toys emotions & really makes you feel for them. But at the end of the day they are just toys! We should not get that involved yet somehow we do! Toy Story has many hidden meanings and gestures which really drive home the message of friendship and love. They are not cheesy, they are touching and realistic. This is what Disney do so well, they make children's films but whilst doing so they create them so they can be related to by adults. The animation is also on the money, this movie is almost 20 years old but looks as good today on Blu Ray as any other animation. Toy Story also has one brilliant soundtrack with several songs which will stay with you long after you have watched it. Overall I cannot recommend this film enough and I would recommend anybody to go and watch it, no matter what your age.A timeless classic. 10/10
# ====================================================================================================
# Original Review Details:
# This is another one of my "I should like this movie better than I do" films. It has an all-star voice-over cast (which I like all of them) - and that is the merit to this film and the story is cute and fun. I did get a few laughs out of the movie so I will not knock the film.So what is it about the film I dislike? The toys - not the actors voicing them - the toys themselves. All of the toys except for Rex (the T. Rex toy). I did enjoy the toon Rex - he was quite the comedy act. Mr. Potato Head was OK in the film but I never liked the toy as a kid - just boring to play with. The rest of the toys (or similar types) never interested me as a kid so they do not appeal to me in this film.It's a shame that I am not keen on this film since I really enjoyed films like "Monsters, Inc.", "Shrek" and "Chicken Run".6/10
#
# Cleaned Review Details:
# This is another one of my "I should like this movie better than I do" films. It has an all-star voice-over cast (which I like all of them) - and that is the merit to this film and the story is cute and fun. I did get a few laughs out of the movie so I will not knock the film.So what is it about the film I dislike? The toys - not the actors voicing them - the toys themselves. All of the toys except for Rex (the T. Rex toy). I did enjoy the toon Rex - he was quite the comedy act. Mr. Potato Head was OK in the film but I never liked the toy as a kid - just boring to play with. The rest of the toys (or similar types) never interested me as a kid so they do not appeal to me in this film.It is a shame that I am not keen on this film since I really enjoyed films like "Monsters, Inc.", "Shrek" and "Chicken Run".6/10
# ====================================================================================================
# Original Review Details:
# So far they have come out with 3 Toy Story movies, and I also saw like a spooky Toy Story movie at RedBox and thought I heard that they are going to make a 4th one. It's interesting to think how this movie is from 1995 and was like the first fully computer animated movie, while nowadays almost all the animated movies we see are computer animated rather than the old days when they were digitally animated drawings. I miss those old cartoon movies. Anyway, Toy Story is definitely a classic movie. Kids today can watch the movie, and it probably won't seem like an old movie to them. They have made other Toy Story movies which seemed to earn more money than the first one. But, I will talk about why the first one is the best. The first one introduced us to the Toys in Toy Story, yeah they add some new toys in the later films, but this one is the first real introduction. It's always nice to remember the introduction of the characters we are familiar with in later films. Also, the later films seem to be more about adventures from the toys we know together in a group, in this movie it was mostly just the adventure of our favorite toys, Woody and Buzz. We see Woody's reaction to having Buzz as the new popular toy. Also, this one seems more about survival for Woody and Buzz, while in the other Toy Story movies it seems like it's less about survival and more about getting back to where they belong. Another reason to like this movie, from what I know while Pizza Planet is mentioned in other Pixar movies, this is the only one which shows them inside a Pizza Planet. I've always thought, that restaurant would be really cool to be at if it were a real restaurant. About Pizza Planet, I remember way back in 6th Grade in the scene when we see the Pizza Planet pick-up truck at the gas station and we hear the guys in it ask for directions to Pizza Planet, somebody in the classroom asked the teacher why would somebody who worked at Pizza Planet be asking for directions on how to get there? My teacher didn't know how to answer. In this movie we get to know Andy's original house and his neighborhood. We get to know the villain in this movie, Sid. The villains in the other movies are like the Chicken Man, Stinky Pete, and Lotso and some of his gang. I'm sure most of us could agree that our favorite bad guy in these Toy Story movies is Sid and let me give a few reasons to why we might like him the best. For one, Sid is Andy's next door neighbor. What's weird is the movie doesn't give any indication of whether Andy and Sid knew each other, so it can leave us with that question. Sid isn't like a bad guy, I mean he plays in the movie as a bad guy, but he seems to play a character we could imagine his age. I mean about a 13 year old boy who wears a T Shirt with a skeleton. He's aggressive and he likes torturing toys as a hobby of his, obviously not aware that the toys are alive. He likes explosives and stuff, and has a dark atmosphere in his room, along with mostly keeping his room locked. So, he's a G rated version of an early adolescent character who is supposed to be like the bad guy and he doesn't swear, talk about alcohol, drugs, or sex. He isn't like a criminal, just a scary kid with a dark atmosphere who likes to be the bad guy to toys he doesn't realize are alive. The climax in this movie also seems more exciting than the climax in the other movies. One thing we can find hard to believe, is how the toys have all these wacky adventures, doing things that somebody could easily notice, and nobody seems to be aware that the Toys are alive. Toy Story doesn't seem like The Velveteen Rabbit, but more like Toys who are having their own adventures, a little like The Lego Movie, where the Toys seem more alive than they seem like Toys. This is a great movie, I'd give a 9/10.
#
# Cleaned Review Details:
# So far they have come out with 3 Toy Story movies, and I also saw like a spooky Toy Story movie at RedBox and thought I heard that they are going to make a 4th one. It is interesting to think how this movie is from 1995 and was like the first fully computer animated movie, while nowadays almost all the animated movies we see are computer animated rather than the old days when they were digitally animated drawings. I miss those old cartoon movies. Anyway, Toy Story is definitely a classic movie. Kids today can watch the movie, and it probably will not seem like an old movie to them. They have made other Toy Story movies which seemed to earn more money than the first one. But, I will talk about why the first one is the best. The first one introduced us to the Toys in Toy Story, yeah they add some new toys in the later films, but this one is the first real introduction. It is always nice to remember the introduction of the characters we are familiar with in later films. Also, the later films seem to be more about adventures from the toys we know together in a group, in this movie it was mostly just the adventure of our favorite toys, Woody and Buzz. We see Woody's reaction to having Buzz as the new popular toy. Also, this one seems more about survival for Woody and Buzz, while in the other Toy Story movies it seems like it is less about survival and more about getting back to where they belong. Another reason to like this movie, from what I know while Pizza Planet is mentioned in other Pixar movies, this is the only one which shows them inside a Pizza Planet. I have always thought, that restaurant would be really cool to be at if it were a real restaurant. About Pizza Planet, I remember way back in 6th Grade in the scene when we see the Pizza Planet pick-up truck at the gas station and we hear the guys in it ask for directions to Pizza Planet, somebody in the classroom asked the teacher why would somebody who worked at Pizza Planet be asking for directions on how to get there? My teacher did not know how to answer. In this movie we get to know Andy's original house and his neighborhood. We get to know the villain in this movie, Sid. The villains in the other movies are like the Chicken Man, Stinky Pete, and Lotso and some of his gang. I am sure most of us could agree that our favorite bad guy in these Toy Story movies is Sid and let me give a few reasons to why we might like him the best. For one, Sid is Andy's next door neighbor. What is weird is the movie does not give any indication of whether Andy and Sid knew each other, so it can leave us with that question. Sid is not like a bad guy, I mean he plays in the movie as a bad guy, but he seems to play a character we could imagine his age. I mean about a 13 year old boy who wears a T Shirt with a skeleton. He is aggressive and he likes torturing toys as a hobby of his, obviously not aware that the toys are alive. He likes explosives and stuff, and has a dark atmosphere in his room, along with mostly keeping his room locked. So, he is a G rated version of an early adolescent character who is supposed to be like the bad guy and he does not swear, talk about alcohol, drugs, or sex. He is not like a criminal, just a scary kid with a dark atmosphere who likes to be the bad guy to toys he does not realize are alive. The climax in this movie also seems more exciting than the climax in the other movies. One thing we can find hard to believe, is how the toys have all these wacky adventures, doing things that somebody could easily notice, and nobody seems to be aware that the Toys are alive. Toy Story does not seem like The Velveteen Rabbit, but more like Toys who are having their own adventures, a little like The Lego Movie, where the Toys seem more alive than they seem like Toys. This is a great movie, I would give a 9/10.
# ====================================================================================================
# Original Review Details:
# Wow, well what can I say! This is a favorite of mine. The voice work in this movie is so great and so natural. Tom Hanks and Tim Allen have such amazing chemistry and you would think that these 2 were actually friends!! Omg, the heart that this story has is so sweet and the main song in it is a classic as well. The side characters in this movie are so sweet and great as well. Mr. Potato Head, Bo Beep, Slinky, Hamm, all of them have such chemistry and energy to their performances. I love how it is in the point of view of the toys and we get to see their lives. One of my favorite scenes is when the army men see what presents Andy gets for his birthday. Aah, I cannot say enough how much I love this movie. It's funny and original and I will continue to love it forever.
#
# Cleaned Review Details:
# Wow, well what can I say! This is a favorite of mine. The voice work in this movie is so great and so natural. Tom Hanks and Tim Allen have such amazing chemistry and you would think that these 2 were actually friends!! Omg, the heart that this story has is so sweet and the main song in it is a classic as well. The side characters in this movie are so sweet and great as well. Mr. Potato Head, Bo Beep, Slinky, Hamm, all of them have such chemistry and energy to their performances. I love how it is in the point of view of the toys and we get to see their lives. One of my favorite scenes is when the army men see what presents Andy gets for his birthday. Aah, I cannot say enough how much I love this movie. It is funny and original and I will continue to love it forever.
# ====================================================================================================

# %% [markdown]
# __Name Entity Recognition (NER)__

# %%
# TODO: Train own NER with the names of crews and casts and other important info

# Load the English language model in spaCy
nlp = spacy.load("en_core_web_sm")

# Create a new dataFrame to store extracted name entitiesm then combine/rename the following labels
# - LOCATION : GPE, LOC and FACE
# - DATE_TIME : DATE, TIME
# - ORGANIZATION : ORG

column_names = ['PERSON', 'WORK_OF_ART', 'LOCATION', 'DATE_TIME', 'ORGANIZATION', 'PRODUCT', 'EVENT', 'LANGUAGE']
movie_name_entities_df = pd.DataFrame(columns=column_names)

# Extract and remove name entities from 'cleaned_review_summary' and 'cleaned_review_detail' columns
movie_reviews_df['cleaned_review_summary'], movie_name_entities_df = tp.extract_name_entity(movie_reviews_df['cleaned_review_summary'], nlp, movie_name_entities_df)
movie_reviews_df['cleaned_review_detail'], movie_name_entities_df = tp.extract_name_entity(movie_reviews_df['cleaned_review_detail'], nlp, movie_name_entities_df)

# Display the comparison between the top 5 original review summaries and their cleaned versions
for i in range(5):
    print("Original Review Summary:")
    print(movie_reviews_df['review_summary'][i])
    print("\nCleaned Review Summary (NER Removed):")
    print(movie_reviews_df['cleaned_review_summary'][i])
    print("="*50)

# Display the comparison between the top 5 original review details and their cleaned versions
for i in range(5):
    print("Original Review Details:")
    print(movie_reviews_df['review_detail'][i])
    print("\nCleaned Review Details (NER Removed):")
    print(movie_reviews_df['cleaned_review_detail'][i])
    print("="*50)
# Out:
# Original Review Summary:
# Can it be ten years already?
#
# Cleaned Review Summary (NER Removed):
# Can it be  already?
# ==================================================
# Original Review Summary:
# A childhood favourite
#
# Cleaned Review Summary (NER Removed):
# A childhood favourite
# ==================================================
# Original Review Summary:
# Not As Good As I Was Hoping
#
# Cleaned Review Summary (NER Removed):
# Not As Good As I Was Hoping
# ==================================================
# Original Review Summary:
# Why The First Toy Story Is My Favorite
#
# Cleaned Review Summary (NER Removed):
# Why The First Toy Story Is My Favorite
# ==================================================
# Original Review Summary:
# A classic friendship story!
#
# Cleaned Review Summary (NER Removed):
# A classic friendship story!
# ==================================================
# Original Review Details:
# PIXAR animation was but an experimental animation company that had a track record of short film contributions to film festivals when Disney invested in and ultimately released their first project,Toy Story. I figured Disney probably had a good feeling about this one,but I'm not sure they anticipated the kind of groundbreaking swell of animation this would shepherd in.The concept is a fitfully simple and cute one: when kids are away,their toys take on personalities and lives of their own,plotting,planning,bickering,reacting,flirting,etc. In this particular den of toys, a Cowboy Woody doll(voiced by Tom Hanks) is the leader,flanked by a Slinky dog(Jim Varney),green toy soldiers(aptly casted R.Lee Ermey as their platoon leader),a Mr.Potato head(Don Rickles), a Piggy bank(John Ratzenberger,forever Cliff Claven from "Cheers") and a Bo Peep doll(Annie Potts). Into the mix is a new,electronic Buzz Lightyear action figure(Tim Allen,who probably does the best voice acting of the bunch here),who almost instantly wows the locals and stirs jealousy from Woody.With music from Randy Newmann--a personal fave of mine--this movie's colors,attention to detail and wry humor make it easily adaptable to kids and adults alike. CAn it really be ten years since this film broke new ground on animation? How time flies in the wake of stuff like "Shrek" and "FInding Nemo"!
#
# Cleaned Review Details (NER Removed):
#  animation was but an experimental animation company that had a track record of short film contributions to film festivals when  invested in and ultimately released their  project,. I figured  probably had a good feeling about this one,but I am not sure they anticipated the kind of groundbreaking swell of animation this would shepherd in.The concept is a fitfully simple and cute one: when kids are away,their toys take on personalities and lives of their own,plotting,planning,bickering,reacting,flirting,etc. In this particular den of toys, a  doll(voiced by ) is the leader,flanked by a Slinky dog(Jim  casted  as their platoon  Mr.), a  ,forever Cliff Claven from "") and a Bo Peep doll(Annie ). Into the mix is a new,electronic  action figure(Tim ,who probably does the best voice acting of the bunch here),who almost instantly wows the locals and stirs jealousy from Woody.With music from --a personal fave of mine--this movie's colors,attention to detail and wry humor make it easily adaptable to kids and adults alike. CAn it really be  since this film broke new ground on animation? How time flies in the wake of stuff like "" and "FInding Nemo"!
# ==================================================
# Original Review Details:
# Toy Story is one of those movies which holds a lot of good childhood memories for me. I first saw it in the cinema as a child, it was then worn out on VHS tape. Played to death on DVD & is now owned on special edition Blu Ray. It is by far, one of my favourite ever movies. Everything about this movie is perfect. It is a subject which is relateable to every single person who has ever watched this film; that our toys came to life when weren't there. In Toy Story the toys don't just simply come to life, they have their own world, their own relationships, their own problems and conflicts. But above all else they have friendship, loyalty & a special togetherness. The story begins with the Toys in Andy's bedroom. It is the day of Andy's birthday party and the toys gather round anxious awaiting the news as to whether a new toy has been given as a birthday present, and if it is to be Andy's new 'favourite toy'. The toy that is handed over as a present is the brand spanking new, space ranger, Buzz Lightyear. All the other toys are all in awe of him, all toys that is, expect for Woody, Andy's current favourite Toy. Woody feels threatened by Buzz and has no patience when Buzz genuinely believes that he is a real space ranger & not a toy. The story progresses sending the toys on an adventure which is like no other seen before!The casting for Toy Story is simply perfect. Tom Hanks & Tim Allen put in fantastic performances as Woody & Buzz. The relationship they create is so believable and they develop fantastic chemistry throughout the film. The best thing about Toy Story is the way it manages to involve you in the film. It makes you feel all of the toys emotions & really makes you feel for them. But at the end of the day they are just toys! We shouldn't get that involved yet somehow we do! Toy Story has many hidden meanings and gestures which really drive home the message of friendship and love. They are not cheesy, they are touching and realistic. This is what Disney do so well, they make children's films but whilst doing so they create them so they can be related to by adults. The animation is also on the money, this movie is almost 20 years old but looks as good today on Blu Ray as any other animation. Toy Story also has one brilliant soundtrack with several songs which will stay with you long after you have watched it. Overall I cannot recommend this film enough and I would recommend anybody to go and watch it, no matter what your age.A timeless classic. 10/10
#
# Cleaned Review Details (NER Removed):
#  is  of those movies which holds a lot of good childhood memories for me. I  saw it in the cinema as a child, it was then worn out on  tape. Played to death on DVD & is now owned on special edition . It is by far,  of my favourite ever movies. Everything about this movie is perfect. It is a subject which is relateable to every single person who has ever watched this film; that our toys came to life when were not there. In  the toys do not just simply come to life, they have their own world, their own relationships, their own problems and conflicts. But above all else they have friendship, loyalty & a special togetherness. The story begins with the Toys in 's bedroom. It is  of 's birthday party and the toys gather round anxious awaiting the news as to whether a new toy has been given as a birthday present, and if it is to be 's new 'favourite toy'. The toy that is handed over as a present is the brand spanking new, space ranger, . All the other toys are all in awe of him, all toys that is, expect for , 's current favourite Toy.  feels threatened by  and has no patience when  genuinely believes that he is a real space ranger & not a toy. The story progresses sending the toys on an adventure which is like no other seen before!The casting for  is simply perfect.  put in fantastic performances as  & . The relationship they create is so believable and they develop fantastic chemistry throughout the film. The best thing about  is the way it manages to involve you in the film. It makes you feel all of the toys emotions & really makes you feel for them. But at the end of  they are just toys! We should not get that involved yet somehow we do!  has many hidden meanings and gestures which really drive home the message of friendship and love. They are not cheesy, they are touching and realistic. This is what  do so well, they make children's films but whilst doing so they create them so they can be related to by adults. The animation is also on the my, this movie is  but looks as good  on  as any other animation.  also has  brilliant soundtrack with several songs which will stay with you long after you have watched it. Overall I cannot recommend this film enough and I would recommend anybody to go and watch it, no matter what your age.A timeless classic. 10/10
# ==================================================
# Original Review Details:
# This is another one of my "I should like this movie better than I do" films. It has an all-star voice-over cast (which I like all of them) - and that is the merit to this film and the story is cute and fun. I did get a few laughs out of the movie so I will not knock the film.So what is it about the film I dislike? The toys - not the actors voicing them - the toys themselves. All of the toys except for Rex (the T. Rex toy). I did enjoy the toon Rex - he was quite the comedy act. Mr. Potato Head was OK in the film but I never liked the toy as a kid - just boring to play with. The rest of the toys (or similar types) never interested me as a kid so they do not appeal to me in this film.It's a shame that I am not keen on this film since I really enjoyed films like "Monsters, Inc.", "Shrek" and "Chicken Run".6/10
#
# Cleaned Review Details (NER Removed):
# This is another one of my "I should like this movie better than I do" films. It has an all-star voice-over cast (which I like all of them) - and that is the merit to this film and the story is cute and fun. I did get a few laughs out of the movie so I will not knock the film.So what is it about the film I dislike? The toys - not the actors voicing them - the toys themselves. All of the toys except for  (the T.  toy). I did enjoy the toon  - he was quite the comedy act. Mr.  was OK in the film but I never liked the toy as a kid - just boring to play with. The rest of the toys (or similar types) never interested me as a kid so they do not appeal to me in this film.It is a shame that I am not keen on this film since I really enjoyed films like "", "" and "Chicken Run".6/10
# ==================================================
# Original Review Details:
# So far they have come out with 3 Toy Story movies, and I also saw like a spooky Toy Story movie at RedBox and thought I heard that they are going to make a 4th one. It's interesting to think how this movie is from 1995 and was like the first fully computer animated movie, while nowadays almost all the animated movies we see are computer animated rather than the old days when they were digitally animated drawings. I miss those old cartoon movies. Anyway, Toy Story is definitely a classic movie. Kids today can watch the movie, and it probably won't seem like an old movie to them. They have made other Toy Story movies which seemed to earn more money than the first one. But, I will talk about why the first one is the best. The first one introduced us to the Toys in Toy Story, yeah they add some new toys in the later films, but this one is the first real introduction. It's always nice to remember the introduction of the characters we are familiar with in later films. Also, the later films seem to be more about adventures from the toys we know together in a group, in this movie it was mostly just the adventure of our favorite toys, Woody and Buzz. We see Woody's reaction to having Buzz as the new popular toy. Also, this one seems more about survival for Woody and Buzz, while in the other Toy Story movies it seems like it's less about survival and more about getting back to where they belong. Another reason to like this movie, from what I know while Pizza Planet is mentioned in other Pixar movies, this is the only one which shows them inside a Pizza Planet. I've always thought, that restaurant would be really cool to be at if it were a real restaurant. About Pizza Planet, I remember way back in 6th Grade in the scene when we see the Pizza Planet pick-up truck at the gas station and we hear the guys in it ask for directions to Pizza Planet, somebody in the classroom asked the teacher why would somebody who worked at Pizza Planet be asking for directions on how to get there? My teacher didn't know how to answer. In this movie we get to know Andy's original house and his neighborhood. We get to know the villain in this movie, Sid. The villains in the other movies are like the Chicken Man, Stinky Pete, and Lotso and some of his gang. I'm sure most of us could agree that our favorite bad guy in these Toy Story movies is Sid and let me give a few reasons to why we might like him the best. For one, Sid is Andy's next door neighbor. What's weird is the movie doesn't give any indication of whether Andy and Sid knew each other, so it can leave us with that question. Sid isn't like a bad guy, I mean he plays in the movie as a bad guy, but he seems to play a character we could imagine his age. I mean about a 13 year old boy who wears a T Shirt with a skeleton. He's aggressive and he likes torturing toys as a hobby of his, obviously not aware that the toys are alive. He likes explosives and stuff, and has a dark atmosphere in his room, along with mostly keeping his room locked. So, he's a G rated version of an early adolescent character who is supposed to be like the bad guy and he doesn't swear, talk about alcohol, drugs, or sex. He isn't like a criminal, just a scary kid with a dark atmosphere who likes to be the bad guy to toys he doesn't realize are alive. The climax in this movie also seems more exciting than the climax in the other movies. One thing we can find hard to believe, is how the toys have all these wacky adventures, doing things that somebody could easily notice, and nobody seems to be aware that the Toys are alive. Toy Story doesn't seem like The Velveteen Rabbit, but more like Toys who are having their own adventures, a little like The Lego Movie, where the Toys seem more alive than they seem like Toys. This is a great movie, I'd give a 9/10.
#
# Cleaned Review Details (NER Removed):
# So far they have come out with   movies, and I also saw like a spooky  movie at  and thought I heard that they are going to make a  . It is interesting to think how this movie is from  and was like the  fully computer animated movie, while nowadays almost all the animated movies we see are computer animated rather than the old days when they were digitally animated drawings. I miss those old cartoon movies. Anyway,  is definitely a classic movie. Kids  can watch the movie, and it probably will not seem like an old movie to them. They have made other  movies which seemed to earn more my than the  . But, I will talk about why the   is the best. The   introduced us to the Toys in , yeah they add some new toys in the later films, but this  is the  real introduction. It is always nice to remember the introduction of the characters we are familiar with in later films. Also, the later films seem to be more about adventures from the toys we know together in a group, in this movie it was mostly just the adventure of our favorite toys,  and . We see 's reaction to having  as the new popular toy. Also, this  seems more about survival for  and , while in the other  movies it seems like it is less about survival and more about getting back to where they belong. Another reason to like this movie, from what I know while  is mentid in other  movies, this is the only  which shows them inside a . I have always thought, that restaurant would be really cool to be at if it were a real restaurant. About , I remember way back in  Grade in the scene when we see the  pick-up truck at the gas station and we hear the guys in it ask for directions to , somebody in the classroom asked the teacher why would somebody who worked at  be asking for directions on how to get there? My teacher did not know how to answer. In this movie we get to know 's original house and his neighborhood. We get to know the villain in this movie, . The villains in the other movies are like the Chicken Man, , and  and some of his gang. I am sure most of us could agree that our favorite bad guy in these  movies is  and let me give a few reasons to why we might like him the best. For ,  is 's next door neighbor. What is weird is the movie does not give any indication of whether  and  knew each other, so it can leave us with that question.  is not like a bad guy, I mean he plays in the movie as a bad guy, but he seems to play a character we could imagine his age. I mean about a 1 year old boy who wears a T Shirt with a skeleton. He is aggressive and he likes torturing toys as a hobby of his, obviously not aware that the toys are alive. He likes explosives and stuff, and has a dark atmosphere in his room, along with mostly keeping his room locked. So, he is a G rated version of an early adolescent character who is supposed to be like the bad guy and he does not swear, talk about alcohol, drugs, or sex. He is not like a criminal, just a scary kid with a dark atmosphere who likes to be the bad guy to toys he does not realize are alive. The climax in this movie also seems more exciting than the climax in the other movies.  thing we can find hard to believe, is how the toys have all these wacky adventures, doing things that somebody could easily notice, and nobody seems to be aware that the Toys are alive.  does not seem like , but more like Toys who are having their own adventures, a little like , where the Toys seem more alive than they seem like Toys. This is a great movie, I would give a .
# ==================================================
# Original Review Details:
# Wow, well what can I say! This is a favorite of mine. The voice work in this movie is so great and so natural. Tom Hanks and Tim Allen have such amazing chemistry and you would think that these 2 were actually friends!! Omg, the heart that this story has is so sweet and the main song in it is a classic as well. The side characters in this movie are so sweet and great as well. Mr. Potato Head, Bo Beep, Slinky, Hamm, all of them have such chemistry and energy to their performances. I love how it is in the point of view of the toys and we get to see their lives. One of my favorite scenes is when the army men see what presents Andy gets for his birthday. Aah, I cannot say enough how much I love this movie. It's funny and original and I will continue to love it forever.
#
# Cleaned Review Details (NER Removed):
# Wow, well what can I say! This is a favorite of mine. The voice work in this movie is so great and so natural.  and  have such amazing chemistry and you would think that these  were actually friends!! Omg, the heart that this story has is so sweet and the main song in it is a classic as well. The side characters in this movie are so sweet and great as well. Mr. , , , , all of them have such chemistry and energy to their performances. I love how it is in the point of view of the toys and we get to see their lives.  of my favorite scenes is when the army men see what presents  gets for his birthday. Aah, I cannot say enough how much I love this movie. It is funny and original and I will continue to love it forever.
# ==================================================

# %%
# Dataframe of the extracted name entities
movie_name_entities_df = pd.merge(movie_reviews_df['imdb_id'], movie_name_entities_df, left_index=True, right_index=True)
movie_name_entities_df.head(5)

# %% [markdown]
# __Utilize regular expressions to eliminate punctuation, substitute whitespaces, transform characters to lowercase, and filter out stopwords from movie reviews__

# %%
# Initialize the English stop words list
list_of_stopwords = set(stopwords.words('english'))

def supplemental_text_preprocessing(text):
    # Remove non-alphanumeric characters except for the following
    # - hyphen (-) that is in between alphanumeric
    text = tp.remove_non_alphanumeric_char(text)
    
    # Remove leading and trailing whitespaces
    text = text.strip()

    # Replace multiple whitespaces with a single space
    text = tp.replace_whitespace(text)

    # Remove stopwords
    text = tp.remove_stopwords(text, list_of_stopwords)

    return text

# Apply text cleaning to 'cleaned_review_summary' and 'cleaned_review_detail' columns
movie_reviews_df[['cleaned_review_summary', 'cleaned_review_detail']] = movie_reviews_df[['cleaned_review_summary', 'cleaned_review_detail']]\
                                                                            .applymap(supplemental_text_preprocessing)

# Display the comparison between the top 5 original review summaries and their cleaned versions
for i in range(5):
    print("Original Review Summary:")
    print(movie_reviews_df['review_summary'][i])
    print("\nCleaned Review Summary (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):")
    print(movie_reviews_df['cleaned_review_summary'][i])
    print("="*100)

# Display the comparison between the top 5 original review details and their cleaned versions
for i in range(5):
    print("Original Review Details:")
    print(movie_reviews_df['review_detail'][i])
    print("\nCleaned Review Details (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):")
    print(movie_reviews_df['cleaned_review_detail'][i])
    print("="*100)
# Out:
# Original Review Summary:
# Can it be ten years already?
#
# Cleaned Review Summary (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# Can already
# ====================================================================================================
# Original Review Summary:
# A childhood favourite
#
# Cleaned Review Summary (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# A childhood favourite
# ====================================================================================================
# Original Review Summary:
# Not As Good As I Was Hoping
#
# Cleaned Review Summary (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# Not As Good As I Was Hoping
# ====================================================================================================
# Original Review Summary:
# Why The First Toy Story Is My Favorite
#
# Cleaned Review Summary (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# Why The First Toy Story Is My Favorite
# ====================================================================================================
# Original Review Summary:
# A classic friendship story!
#
# Cleaned Review Summary (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# A classic friendship story
# ====================================================================================================
# Original Review Details:
# PIXAR animation was but an experimental animation company that had a track record of short film contributions to film festivals when Disney invested in and ultimately released their first project,Toy Story. I figured Disney probably had a good feeling about this one,but I'm not sure they anticipated the kind of groundbreaking swell of animation this would shepherd in.The concept is a fitfully simple and cute one: when kids are away,their toys take on personalities and lives of their own,plotting,planning,bickering,reacting,flirting,etc. In this particular den of toys, a Cowboy Woody doll(voiced by Tom Hanks) is the leader,flanked by a Slinky dog(Jim Varney),green toy soldiers(aptly casted R.Lee Ermey as their platoon leader),a Mr.Potato head(Don Rickles), a Piggy bank(John Ratzenberger,forever Cliff Claven from "Cheers") and a Bo Peep doll(Annie Potts). Into the mix is a new,electronic Buzz Lightyear action figure(Tim Allen,who probably does the best voice acting of the bunch here),who almost instantly wows the locals and stirs jealousy from Woody.With music from Randy Newmann--a personal fave of mine--this movie's colors,attention to detail and wry humor make it easily adaptable to kids and adults alike. CAn it really be ten years since this film broke new ground on animation? How time flies in the wake of stuff like "Shrek" and "FInding Nemo"!
#
# Cleaned Review Details (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# animation experimental animation company track record short film contributions film festivals invested ultimately released project I figured probably good feeling one I sure anticipated kind groundbreaking swell animation would shepherd The concept fitfully simple cute one kids away toys take personalities lives plotting planning bickering reacting flirting etc In particular den toys doll voiced leader flanked Slinky dog Jim casted platoon Mr forever Cliff Claven Bo Peep doll Annie Into mix new electronic action figure Tim probably best voice acting bunch almost instantly wows locals stirs jealousy Woody With music personal fave mine movie colors attention detail wry humor make easily adaptable kids adults alike CAn really since film broke new ground animation How time flies wake stuff like FInding Nemo
# ====================================================================================================
# Original Review Details:
# Toy Story is one of those movies which holds a lot of good childhood memories for me. I first saw it in the cinema as a child, it was then worn out on VHS tape. Played to death on DVD & is now owned on special edition Blu Ray. It is by far, one of my favourite ever movies. Everything about this movie is perfect. It is a subject which is relateable to every single person who has ever watched this film; that our toys came to life when weren't there. In Toy Story the toys don't just simply come to life, they have their own world, their own relationships, their own problems and conflicts. But above all else they have friendship, loyalty & a special togetherness. The story begins with the Toys in Andy's bedroom. It is the day of Andy's birthday party and the toys gather round anxious awaiting the news as to whether a new toy has been given as a birthday present, and if it is to be Andy's new 'favourite toy'. The toy that is handed over as a present is the brand spanking new, space ranger, Buzz Lightyear. All the other toys are all in awe of him, all toys that is, expect for Woody, Andy's current favourite Toy. Woody feels threatened by Buzz and has no patience when Buzz genuinely believes that he is a real space ranger & not a toy. The story progresses sending the toys on an adventure which is like no other seen before!The casting for Toy Story is simply perfect. Tom Hanks & Tim Allen put in fantastic performances as Woody & Buzz. The relationship they create is so believable and they develop fantastic chemistry throughout the film. The best thing about Toy Story is the way it manages to involve you in the film. It makes you feel all of the toys emotions & really makes you feel for them. But at the end of the day they are just toys! We shouldn't get that involved yet somehow we do! Toy Story has many hidden meanings and gestures which really drive home the message of friendship and love. They are not cheesy, they are touching and realistic. This is what Disney do so well, they make children's films but whilst doing so they create them so they can be related to by adults. The animation is also on the money, this movie is almost 20 years old but looks as good today on Blu Ray as any other animation. Toy Story also has one brilliant soundtrack with several songs which will stay with you long after you have watched it. Overall I cannot recommend this film enough and I would recommend anybody to go and watch it, no matter what your age.A timeless classic. 10/10
#
# Cleaned Review Details (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# movies holds lot good childhood memories I saw cinema child worn tape Played death DVD owned special edition It far favourite ever movies Everything movie perfect It subject relateable every single person ever watched film toys came life In toys simply come life world relationships problems conflicts But else friendship loyalty special togetherness The story begins Toys bedroom It birthday party toys gather round anxious awaiting news whether new toy given birthday present new favourite toy The toy handed present brand spanking new space ranger All toys awe toys expect current favourite Toy feels threatened patience genuinely believes real space ranger toy The story progresses sending toys adventure like seen The casting simply perfect put fantastic performances The relationship create believable develop fantastic chemistry throughout film The best thing way manages involve film It makes feel toys emotions really makes feel But end toys We get involved yet somehow many hidden meanings gestures really drive home message friendship love They cheesy touching realistic This well make children films whilst create related adults The animation also movie looks good animation also brilliant soundtrack several songs stay long watched Overall I recommend film enough I would recommend anybody go watch matter age A timeless classic
# ====================================================================================================
# Original Review Details:
# This is another one of my "I should like this movie better than I do" films. It has an all-star voice-over cast (which I like all of them) - and that is the merit to this film and the story is cute and fun. I did get a few laughs out of the movie so I will not knock the film.So what is it about the film I dislike? The toys - not the actors voicing them - the toys themselves. All of the toys except for Rex (the T. Rex toy). I did enjoy the toon Rex - he was quite the comedy act. Mr. Potato Head was OK in the film but I never liked the toy as a kid - just boring to play with. The rest of the toys (or similar types) never interested me as a kid so they do not appeal to me in this film.It's a shame that I am not keen on this film since I really enjoyed films like "Monsters, Inc.", "Shrek" and "Chicken Run".6/10
#
# Cleaned Review Details (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# This another one I like movie better I films It cast I like merit film story cute fun I get laughs movie I knock film So film I dislike The toys actors voicing toys All toys except T toy I enjoy toon quite comedy act Mr OK film I never liked toy kid boring play The rest toys similar types never interested kid appeal film It shame I keen film since I really enjoyed films like Chicken Run
# ====================================================================================================
# Original Review Details:
# So far they have come out with 3 Toy Story movies, and I also saw like a spooky Toy Story movie at RedBox and thought I heard that they are going to make a 4th one. It's interesting to think how this movie is from 1995 and was like the first fully computer animated movie, while nowadays almost all the animated movies we see are computer animated rather than the old days when they were digitally animated drawings. I miss those old cartoon movies. Anyway, Toy Story is definitely a classic movie. Kids today can watch the movie, and it probably won't seem like an old movie to them. They have made other Toy Story movies which seemed to earn more money than the first one. But, I will talk about why the first one is the best. The first one introduced us to the Toys in Toy Story, yeah they add some new toys in the later films, but this one is the first real introduction. It's always nice to remember the introduction of the characters we are familiar with in later films. Also, the later films seem to be more about adventures from the toys we know together in a group, in this movie it was mostly just the adventure of our favorite toys, Woody and Buzz. We see Woody's reaction to having Buzz as the new popular toy. Also, this one seems more about survival for Woody and Buzz, while in the other Toy Story movies it seems like it's less about survival and more about getting back to where they belong. Another reason to like this movie, from what I know while Pizza Planet is mentioned in other Pixar movies, this is the only one which shows them inside a Pizza Planet. I've always thought, that restaurant would be really cool to be at if it were a real restaurant. About Pizza Planet, I remember way back in 6th Grade in the scene when we see the Pizza Planet pick-up truck at the gas station and we hear the guys in it ask for directions to Pizza Planet, somebody in the classroom asked the teacher why would somebody who worked at Pizza Planet be asking for directions on how to get there? My teacher didn't know how to answer. In this movie we get to know Andy's original house and his neighborhood. We get to know the villain in this movie, Sid. The villains in the other movies are like the Chicken Man, Stinky Pete, and Lotso and some of his gang. I'm sure most of us could agree that our favorite bad guy in these Toy Story movies is Sid and let me give a few reasons to why we might like him the best. For one, Sid is Andy's next door neighbor. What's weird is the movie doesn't give any indication of whether Andy and Sid knew each other, so it can leave us with that question. Sid isn't like a bad guy, I mean he plays in the movie as a bad guy, but he seems to play a character we could imagine his age. I mean about a 13 year old boy who wears a T Shirt with a skeleton. He's aggressive and he likes torturing toys as a hobby of his, obviously not aware that the toys are alive. He likes explosives and stuff, and has a dark atmosphere in his room, along with mostly keeping his room locked. So, he's a G rated version of an early adolescent character who is supposed to be like the bad guy and he doesn't swear, talk about alcohol, drugs, or sex. He isn't like a criminal, just a scary kid with a dark atmosphere who likes to be the bad guy to toys he doesn't realize are alive. The climax in this movie also seems more exciting than the climax in the other movies. One thing we can find hard to believe, is how the toys have all these wacky adventures, doing things that somebody could easily notice, and nobody seems to be aware that the Toys are alive. Toy Story doesn't seem like The Velveteen Rabbit, but more like Toys who are having their own adventures, a little like The Lego Movie, where the Toys seem more alive than they seem like Toys. This is a great movie, I'd give a 9/10.
#
# Cleaned Review Details (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# So far come movies I also saw like spooky movie thought I heard going make It interesting think movie like fully computer animated movie nowadays almost animated movies see computer animated rather old days digitally animated drawings I miss old cartoon movies Anyway definitely classic movie Kids watch movie probably seem like old movie They made movies seemed earn But I talk best The introduced us Toys yeah add new toys later films real introduction It always nice remember introduction characters familiar later films Also later films seem adventures toys know together group movie mostly adventure favorite toys We see reaction new popular toy Also seems survival movies seems like less survival getting back belong Another reason like movie I know mentid movies shows inside I always thought restaurant would really cool real restaurant About I remember way back Grade scene see truck gas station hear guys ask directions somebody classroom asked teacher would somebody worked asking directions get My teacher know answer In movie get know original house neighborhood We get know villain movie The villains movies like Chicken Man gang I sure us could agree favorite bad guy movies let give reasons might like best For next door neighbor What weird movie give indication whether knew leave us question like bad guy I mean plays movie bad guy seems play character could imagine age I mean year old boy wears T Shirt skeleton He aggressive likes torturing toys hobby obviously aware toys alive He likes explosives stuff dark atmosphere room along mostly keeping room locked So G rated version early adolescent character supposed like bad guy swear talk alcohol drugs sex He like criminal scary kid dark atmosphere likes bad guy toys realize alive The climax movie also seems exciting climax movies thing find hard believe toys wacky adventures things somebody could easily notice nobody seems aware Toys alive seem like like Toys adventures little like Toys seem alive seem like Toys This great movie I would give
# ====================================================================================================
# Original Review Details:
# Wow, well what can I say! This is a favorite of mine. The voice work in this movie is so great and so natural. Tom Hanks and Tim Allen have such amazing chemistry and you would think that these 2 were actually friends!! Omg, the heart that this story has is so sweet and the main song in it is a classic as well. The side characters in this movie are so sweet and great as well. Mr. Potato Head, Bo Beep, Slinky, Hamm, all of them have such chemistry and energy to their performances. I love how it is in the point of view of the toys and we get to see their lives. One of my favorite scenes is when the army men see what presents Andy gets for his birthday. Aah, I cannot say enough how much I love this movie. It's funny and original and I will continue to love it forever.
#
# Cleaned Review Details (Non-alphanumeric Characters Removed, Lowercased, Extra Whitespaces Removed, Stopwords Removed):
# Wow well I say This favorite mine The voice work movie great natural amazing chemistry would think actually friends Omg heart story sweet main song classic well The side characters movie sweet great well Mr chemistry energy performances I love point view toys get see lives favorite scenes army men see presents gets birthday Aah I say enough much I love movie It funny original I continue love forever
# ====================================================================================================

# %% [markdown]
# __Implement Spacy's lemmatization on movie reviews, emphasizing the significance of lemmatization in capturing the base or root form of words__

# %%
# TODO: Words with hyphen are being tokenized or split

# Load the spaCy language model
# See: https://spacy.io/usage/models
nlp = spacy.load("en_core_web_sm")
    
# Apply lemmatization to 'review_summary' and 'review_detail' columns
movie_reviews_df['cleaned_review_summary'] = tp.lemmatize_text(movie_reviews_df['cleaned_review_summary'], nlp)
movie_reviews_df['cleaned_review_detail'] = tp.lemmatize_text(movie_reviews_df['cleaned_review_detail'], nlp)

# Display the comparison between the top 5 original review summaries and their lemmatized versions
for i in range(5):
    print("Original Review Summary:")
    print(movie_reviews_df['review_summary'][i])
    print("\nLemmatized Review Summary:")
    print(movie_reviews_df['cleaned_review_summary'][i])
    print("="*100)

# Display the comparison between the top 5 original review details and their lemmatized versions
for i in range(5):
    print("Original Review Details:")
    print(movie_reviews_df['review_detail'][i])
    print("\nLemmatized Review Details:")
    print(movie_reviews_df['cleaned_review_detail'][i])
    print("="*100)
# Out:
# Original Review Summary:
# Can it be ten years already?
#
# Lemmatized Review Summary:
#
# ====================================================================================================
# Original Review Summary:
# A childhood favourite
#
# Lemmatized Review Summary:
# childhood favourite
# ====================================================================================================
# Original Review Summary:
# Not As Good As I Was Hoping
#
# Lemmatized Review Summary:
# good hope
# ====================================================================================================
# Original Review Summary:
# Why The First Toy Story Is My Favorite
#
# Lemmatized Review Summary:
# First Toy Story favorite
# ====================================================================================================
# Original Review Summary:
# A classic friendship story!
#
# Lemmatized Review Summary:
# classic friendship story
# ====================================================================================================
# Original Review Details:
# PIXAR animation was but an experimental animation company that had a track record of short film contributions to film festivals when Disney invested in and ultimately released their first project,Toy Story. I figured Disney probably had a good feeling about this one,but I'm not sure they anticipated the kind of groundbreaking swell of animation this would shepherd in.The concept is a fitfully simple and cute one: when kids are away,their toys take on personalities and lives of their own,plotting,planning,bickering,reacting,flirting,etc. In this particular den of toys, a Cowboy Woody doll(voiced by Tom Hanks) is the leader,flanked by a Slinky dog(Jim Varney),green toy soldiers(aptly casted R.Lee Ermey as their platoon leader),a Mr.Potato head(Don Rickles), a Piggy bank(John Ratzenberger,forever Cliff Claven from "Cheers") and a Bo Peep doll(Annie Potts). Into the mix is a new,electronic Buzz Lightyear action figure(Tim Allen,who probably does the best voice acting of the bunch here),who almost instantly wows the locals and stirs jealousy from Woody.With music from Randy Newmann--a personal fave of mine--this movie's colors,attention to detail and wry humor make it easily adaptable to kids and adults alike. CAn it really be ten years since this film broke new ground on animation? How time flies in the wake of stuff like "Shrek" and "FInding Nemo"!
#
# Lemmatized Review Details:
# animation experimental animation company track record short film contribution film festival invest ultimately release project figure probably good feeling sure anticipate kind groundbreake swell animation shepherd concept fitfully simple cute kid away toy personality live plot planning bickering react flirt etc particular den toy doll voice leader flank slinky dog Jim cast platoon Mr forever Cliff Claven Bo Peep doll Annie mix new electronic action figure Tim probably good voice acting bunch instantly wow local stir jealousy Woody music personal fave movie color attention detail wry humor easily adaptable kid adult alike film break new ground animation time fly wake stuff like FInding Nemo
# ====================================================================================================
# Original Review Details:
# Toy Story is one of those movies which holds a lot of good childhood memories for me. I first saw it in the cinema as a child, it was then worn out on VHS tape. Played to death on DVD & is now owned on special edition Blu Ray. It is by far, one of my favourite ever movies. Everything about this movie is perfect. It is a subject which is relateable to every single person who has ever watched this film; that our toys came to life when weren't there. In Toy Story the toys don't just simply come to life, they have their own world, their own relationships, their own problems and conflicts. But above all else they have friendship, loyalty & a special togetherness. The story begins with the Toys in Andy's bedroom. It is the day of Andy's birthday party and the toys gather round anxious awaiting the news as to whether a new toy has been given as a birthday present, and if it is to be Andy's new 'favourite toy'. The toy that is handed over as a present is the brand spanking new, space ranger, Buzz Lightyear. All the other toys are all in awe of him, all toys that is, expect for Woody, Andy's current favourite Toy. Woody feels threatened by Buzz and has no patience when Buzz genuinely believes that he is a real space ranger & not a toy. The story progresses sending the toys on an adventure which is like no other seen before!The casting for Toy Story is simply perfect. Tom Hanks & Tim Allen put in fantastic performances as Woody & Buzz. The relationship they create is so believable and they develop fantastic chemistry throughout the film. The best thing about Toy Story is the way it manages to involve you in the film. It makes you feel all of the toys emotions & really makes you feel for them. But at the end of the day they are just toys! We shouldn't get that involved yet somehow we do! Toy Story has many hidden meanings and gestures which really drive home the message of friendship and love. They are not cheesy, they are touching and realistic. This is what Disney do so well, they make children's films but whilst doing so they create them so they can be related to by adults. The animation is also on the money, this movie is almost 20 years old but looks as good today on Blu Ray as any other animation. Toy Story also has one brilliant soundtrack with several songs which will stay with you long after you have watched it. Overall I cannot recommend this film enough and I would recommend anybody to go and watch it, no matter what your age.A timeless classic. 10/10
#
# Lemmatized Review Details:
# movie hold lot good childhood memory cinema child worn tape play death DVD special edition far favourite movie movie perfect subject relateable single person watch film toy come life toy simply come life world relationship problem conflict friendship loyalty special togetherness story begin toy bedroom birthday party toy gather round anxious await news new toy birthday present new favourite toy toy hand present brand spank new space ranger toy awe toy expect current favourite Toy feel threaten patience genuinely believe real space ranger toy story progress send toy adventure like casting simply perfect fantastic performance relationship create believable develop fantastic chemistry film good thing way manage involve film feel toy emotion feel end toy involve hide meaning gesture drive home message friendship love cheesy touch realistic child film whilst create relate adult animation movie look good animation brilliant soundtrack song stay long watch Overall recommend film recommend anybody watch matter age timeless classic
# ====================================================================================================
# Original Review Details:
# This is another one of my "I should like this movie better than I do" films. It has an all-star voice-over cast (which I like all of them) - and that is the merit to this film and the story is cute and fun. I did get a few laughs out of the movie so I will not knock the film.So what is it about the film I dislike? The toys - not the actors voicing them - the toys themselves. All of the toys except for Rex (the T. Rex toy). I did enjoy the toon Rex - he was quite the comedy act. Mr. Potato Head was OK in the film but I never liked the toy as a kid - just boring to play with. The rest of the toys (or similar types) never interested me as a kid so they do not appeal to me in this film.It's a shame that I am not keen on this film since I really enjoyed films like "Monsters, Inc.", "Shrek" and "Chicken Run".6/10
#
# Lemmatized Review Details:
# like movie film cast like merit film story cute fun laugh movie knock film film dislike toy actor voice toy toy toy enjoy toon comedy act Mr ok film like toy kid boring play rest toy similar type interested kid appeal film shame keen film enjoy film like Chicken Run
# ====================================================================================================
# Original Review Details:
# So far they have come out with 3 Toy Story movies, and I also saw like a spooky Toy Story movie at RedBox and thought I heard that they are going to make a 4th one. It's interesting to think how this movie is from 1995 and was like the first fully computer animated movie, while nowadays almost all the animated movies we see are computer animated rather than the old days when they were digitally animated drawings. I miss those old cartoon movies. Anyway, Toy Story is definitely a classic movie. Kids today can watch the movie, and it probably won't seem like an old movie to them. They have made other Toy Story movies which seemed to earn more money than the first one. But, I will talk about why the first one is the best. The first one introduced us to the Toys in Toy Story, yeah they add some new toys in the later films, but this one is the first real introduction. It's always nice to remember the introduction of the characters we are familiar with in later films. Also, the later films seem to be more about adventures from the toys we know together in a group, in this movie it was mostly just the adventure of our favorite toys, Woody and Buzz. We see Woody's reaction to having Buzz as the new popular toy. Also, this one seems more about survival for Woody and Buzz, while in the other Toy Story movies it seems like it's less about survival and more about getting back to where they belong. Another reason to like this movie, from what I know while Pizza Planet is mentioned in other Pixar movies, this is the only one which shows them inside a Pizza Planet. I've always thought, that restaurant would be really cool to be at if it were a real restaurant. About Pizza Planet, I remember way back in 6th Grade in the scene when we see the Pizza Planet pick-up truck at the gas station and we hear the guys in it ask for directions to Pizza Planet, somebody in the classroom asked the teacher why would somebody who worked at Pizza Planet be asking for directions on how to get there? My teacher didn't know how to answer. In this movie we get to know Andy's original house and his neighborhood. We get to know the villain in this movie, Sid. The villains in the other movies are like the Chicken Man, Stinky Pete, and Lotso and some of his gang. I'm sure most of us could agree that our favorite bad guy in these Toy Story movies is Sid and let me give a few reasons to why we might like him the best. For one, Sid is Andy's next door neighbor. What's weird is the movie doesn't give any indication of whether Andy and Sid knew each other, so it can leave us with that question. Sid isn't like a bad guy, I mean he plays in the movie as a bad guy, but he seems to play a character we could imagine his age. I mean about a 13 year old boy who wears a T Shirt with a skeleton. He's aggressive and he likes torturing toys as a hobby of his, obviously not aware that the toys are alive. He likes explosives and stuff, and has a dark atmosphere in his room, along with mostly keeping his room locked. So, he's a G rated version of an early adolescent character who is supposed to be like the bad guy and he doesn't swear, talk about alcohol, drugs, or sex. He isn't like a criminal, just a scary kid with a dark atmosphere who likes to be the bad guy to toys he doesn't realize are alive. The climax in this movie also seems more exciting than the climax in the other movies. One thing we can find hard to believe, is how the toys have all these wacky adventures, doing things that somebody could easily notice, and nobody seems to be aware that the Toys are alive. Toy Story doesn't seem like The Velveteen Rabbit, but more like Toys who are having their own adventures, a little like The Lego Movie, where the Toys seem more alive than they seem like Toys. This is a great movie, I'd give a 9/10.
#
# Lemmatized Review Details:
# far come movie like spooky movie think hear interesting think movie like fully computer animate movie nowadays animate movie computer animate old day digitally animate drawing miss old cartoon movie definitely classic movie kid watch movie probably like old movie movie earn talk good introduce toy yeah add new toy later film real introduction nice remember introduction character familiar later film later film adventure toy know group movie adventure favorite toy reaction new popular toy survival movie like survival belong reason like movie know mentid movie inside think restaurant cool real restaurant remember way Grade scene truck gas station hear guy ask direction somebody classroom ask teacher somebody work ask direction teacher know answer movie know original house neighborhood know villain movie villain movie like Chicken Man gang sure agree favorite bad guy movie let reason like good door neighbor weird movie indication know leave question like bad guy mean play movie bad guy play character imagine age mean year old boy wear Shirt skeleton aggressive like torture toy hobby obviously aware toy alive like explosive stuff dark atmosphere room room lock rate version early adolescent character suppose like bad guy swear talk alcohol drug sex like criminal scary kid dark atmosphere like bad guy toy realize alive climax movie exciting climax movie thing find hard believe toy wacky adventure thing somebody easily notice aware toy alive like like toy adventure little like toy alive like toy great movie
# ====================================================================================================
# Original Review Details:
# Wow, well what can I say! This is a favorite of mine. The voice work in this movie is so great and so natural. Tom Hanks and Tim Allen have such amazing chemistry and you would think that these 2 were actually friends!! Omg, the heart that this story has is so sweet and the main song in it is a classic as well. The side characters in this movie are so sweet and great as well. Mr. Potato Head, Bo Beep, Slinky, Hamm, all of them have such chemistry and energy to their performances. I love how it is in the point of view of the toys and we get to see their lives. One of my favorite scenes is when the army men see what presents Andy gets for his birthday. Aah, I cannot say enough how much I love this movie. It's funny and original and I will continue to love it forever.
#
# Lemmatized Review Details:
# wow favorite voice work movie great natural amazing chemistry think actually friend Omg heart story sweet main song classic character movie sweet great Mr chemistry energy performance love point view toy life favorite scene army man present birthday Aah love movie funny original continue love forever
# ====================================================================================================

# %%
# Drop the old reviews and detail, replacing them with the pre-processed one
movie_reviews_df['review_summary'] = movie_reviews_df['cleaned_review_summary']
movie_reviews_df['review_detail'] = movie_reviews_df['cleaned_review_detail']

movie_reviews_df = movie_reviews_df.drop(columns=['cleaned_review_summary', 'cleaned_review_detail'], axis=1)
movie_reviews_df.head(5)
# Out:
#    imdb_id            review_summary  \
# 0   114709
# 1   114709       childhood favourite
# 2   114709                 good hope
# 3   114709  First Toy Story favorite
# 4   114709  classic friendship story
#
#                                        review_detail  roberta_sentiment  \
# 0  animation experimental animation company track...           Positive
# 1  movie hold lot good childhood memory cinema ch...  Strongly Positive
# 2  like movie film cast like merit film story cut...            Neutral
# 3  far come movie like spooky movie think hear in...           Positive
# 4  wow favorite voice work movie great natural am...  Strongly Positive
#
#    review_year
# 0         2005
# 1         2014
# 2         2014
# 3         2014
# 4         2017

# %% [markdown]
# Generate word clouds the can help to visualize the most frequent words in the review_details and review_summary columns

# %%
# Function to generate word cloud from BoW and display top 10 words with count and BoW percentage in a table
def generate_wordcloud_with_table(bow_matrix, title):
    feature_names = vectorizer.get_feature_names_out()
    word_freq = dict(zip(feature_names, bow_matrix.sum(axis=0).tolist()[0]))
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
    
    # Get total words in BoW
    total_words_bow = sum(word_freq.values())
    
    # Get top 10 words with counts and calculate their percentages based on BoW
    top_10_words = Counter(word_freq).most_common(10)
    table_data = [['Word', 'Frequency', 'Percentage (of BoW)']]
    
    for word, freq in top_10_words:
        bow_percentage = round((freq / total_words_bow) * 100, 2)
        table_data.append([word, freq, f"{bow_percentage}%"])

    # Display word cloud and table showing top 10 words, their frequency, and BoW percentages
    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    
    plt.subplot(2, 1, 2)
    table = plt.table(cellText=table_data, loc='center', cellLoc='center', colColours=['lightgray'] * 3)
    table.auto_set_font_size(False)
    table.set_fontsize(10)
    table.scale(1, 1.5)

    plt.axis('off')
    plt.tight_layout()
    plt.show()


sentiment_list = [['Positive', 'Strongly Positive'], ['Neutral'], ['Negative', 'Strongly Negative']]

for sentiment in sentiment_list:
    query_result = movie_reviews_df.query("roberta_sentiment in " + str(sentiment))

    # Generate word cloud and display top 10 words with frequency and BoW percentage for review detail BoW
    review_detail_bow = vectorizer.fit_transform(query_result['review_detail'])
    generate_wordcloud_with_table(review_detail_bow, 'Review Detail ' + str(sentiment))

    # Generate word cloud and display top 10 words with frequency and BoW percentage for review summary BoW
    review_summary_bow = vectorizer.fit_transform(query_result['review_summary'])
    generate_wordcloud_with_table(review_summary_bow, 'Review Summary ' + str(sentiment))

# %% [markdown]
# #### __For Feature Selection and Engineering__:

# %%
# Combine 'positive' and 'strongly positive' reviews, and 'negative' and 'strongly negative' reciews
movie_reviews_df['roberta_sentiment'] = movie_reviews_df['roberta_sentiment'].replace('Strongly Positive', 'Positive')
movie_reviews_df['roberta_sentiment'] = movie_reviews_df['roberta_sentiment'].replace('Strongly Negative', 'Negative')
movie_reviews_df['roberta_sentiment'].value_counts().unique
# Out:
# <bound method Series.unique of Positive    251755
# Neutral     157375
# Negative    121294
# Name: roberta_sentiment, dtype: int64>

# %%
# Transform 'roberta_sentiment' feature into a numerical representation [Negative:0, Neutral:1, Positive:2]
encoder = LabelEncoder()
movie_reviews_df['roberta_sentiment_encoded'] = encoder.fit_transform(movie_reviews_df['roberta_sentiment'])
movie_reviews_df.head(5)
# Out:
#    imdb_id            review_summary  \
# 0   114709
# 1   114709       childhood favourite
# 2   114709                 good hope
# 3   114709  First Toy Story favorite
# 4   114709  classic friendship story
#
#                                        review_detail roberta_sentiment  \
# 0  animation experimental animation company track...          Positive
# 1  movie hold lot good childhood memory cinema ch...          Positive
# 2  like movie film cast like merit film story cut...           Neutral
# 3  far come movie like spooky movie think hear in...          Positive
# 4  wow favorite voice work movie great natural am...          Positive
#
#    review_year  roberta_sentiment_encoded
# 0         2005                          2
# 1         2014                          2
# 2         2014                          1
# 3         2014                          2
# 4         2017                          2

# %% [markdown]
# ## Model Creation and Evaluation

# %%
# Separate independent variable from dependent variable
x = movie_reviews_df['review_summary'] + ' ' + movie_reviews_df['review_detail']
y = movie_reviews_df['roberta_sentiment_encoded'].values

print(f"Independent Features: {x.shape}")
print(f"Dependent Features: {y.shape}")
# Out:
# Independent Features: (530424,)
# Dependent Features: (530424,)

# %%
# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# __Multinomial Naive Bayes using TF-IDF__

# %%
# Vectorize the text data using TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
x_train_tfidf = tfidf_vectorizer.fit_transform(x_train)
x_test_tfidf = tfidf_vectorizer.transform(x_test)

# Use Multinomial Naive Bayes to build a model for sentiment analysis
mnb_tfidf_model = MultinomialNB()
mnb_tfidf_model.fit(x_train_tfidf, y_train)
print(f"Model: {mnb_tfidf_model}\n")

# Model evaluation for the Multinomial Naive Bayes using TfidfVectorizer
y_pred = mnb_tfidf_model.predict(x_test_tfidf)

print("Multinomial Naive Bayes using TF-IDF:")
print(classification_report(y_test, y_pred))
# Out:
# Model: MultinomialNB()
#
# Multinomial Naive Bayes using TF-IDF:
#               precision    recall  f1-score   support
#
#            0       0.92      0.25      0.40     24353
#            1       0.62      0.43      0.51     31462
#            2       0.62      0.95      0.75     50270
#
#     accuracy                           0.64    106085
#    macro avg       0.72      0.54      0.55    106085
# weighted avg       0.69      0.64      0.60    106085

# %% [markdown]
# __Multinomial Naive Bayes using CountVectorizer__

# %%
# Vectorize the text data using CountVectorizer
vectorizer = CountVectorizer()
x_train_vect = vectorizer.fit_transform(x_train)
x_test_vect = vectorizer.transform(x_test)

# Use Multinomial Naive Bayes to build a model for sentiment analysis
mnb_vc_model = MultinomialNB()
mnb_vc_model.fit(x_train_vect, y_train)
print(f"Model: {mnb_vc_model}\n")

# Model evaluation for the Multinomial Naive Bayes using CountVectorizer
y_pred = mnb_vc_model.predict(x_test_vect)

print("Multinomial Naive Bayes using CountVectorizer:")
print(classification_report(y_test, y_pred))
# Out:
# Model: MultinomialNB()
#
# Multinomial Naive Bayes using CountVectorizer:
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67     24353
#            1       0.63      0.53      0.58     31462
#            2       0.78      0.82      0.80     50270
#
#     accuracy                           0.71    106085
#    macro avg       0.68      0.69      0.68    106085
# weighted avg       0.70      0.71      0.70    106085

# %% [markdown]
# __Observation:__ After evaluating CountVectorizer and TF-IDF for data vectorization, the former yielded a better accuracy score of 71%, outperforming the TF-IDF model, which achieved only 64% accuracy. Additionally, CountVectorizer produced better F1-scores across all classes, leading us to choose it for data vectorization.

# %% [markdown]
# #### __For Hyperparameter Tuning__:
#
# Evaluate different alpha values to identify the one with the highest precision by using accuracy and precision as scoring metrics

# %%
# Use different set of alpha to test which one produces highest accuracy

param_grid = {'alpha': [0.5, 1.0, 2.0, 3.0]}   # Specify model parameters

multinomial_nb_model = MultinomialNB()
grid_search_cv = GridSearchCV(estimator=multinomial_nb_model, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search_cv.fit(x_train_vect, y_train)

# Get the best parameter and apply it in the model
best_alpha = grid_search_cv.best_params_['alpha']
best_mnb_acc_model = MultinomialNB(alpha=best_alpha)
best_mnb_acc_model.fit(x_train_vect, y_train)
print(f"Model: {best_mnb_acc_model}\n")

# Model evaluation for the Multinomial Naive Bayes using CountVectorizer
y_pred = best_mnb_acc_model.predict(x_test_vect)
print(classification_report(y_test, y_pred))
# Out:
# Model: MultinomialNB(alpha=3.0)
#
#               precision    recall  f1-score   support
#
#            0       0.68      0.65      0.67     24353
#            1       0.62      0.56      0.59     31462
#            2       0.77      0.83      0.80     50270
#
#     accuracy                           0.71    106085
#    macro avg       0.69      0.68      0.68    106085
# weighted avg       0.70      0.71      0.71    106085

# %%
# Use different set of alpha to test which one produces highest precision

param_grid = {'alpha': [0.001, 0.5, 1.0, 1.5]}  # Specify model parameters

multinomial_nb_model = MultinomialNB()
grid_search_cv = GridSearchCV(estimator=multinomial_nb_model, param_grid=param_grid, cv=5, scoring='precision')
grid_search_cv.fit(x_train_vect, y_train)

# Get the best parameter and apply it in the model
best_alpha = grid_search_cv.best_params_['alpha']
best_mnb_pre_model = MultinomialNB(alpha=best_alpha)
best_mnb_pre_model.fit(x_train_vect, y_train)
print(f"Model: {best_mnb_pre_model}\n")

# Model evaluation for the Multinomial Naive Bayes using CountVectorizer
y_pred = best_mnb_pre_model.predict(x_test_vect)
print(classification_report(y_test, y_pred))
# Out:
# Model: MultinomialNB(alpha=0.001)
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.70      0.66     24353
#            1       0.61      0.53      0.57     31462
#            2       0.78      0.80      0.79     50270
#
#     accuracy                           0.70    106085
#    macro avg       0.67      0.68      0.67    106085
# weighted avg       0.69      0.70      0.69    106085

# %% [markdown]
# __Observation:__ There is small difference observed when changing the alpha or learning rate values using GridSearchCV. It becomes evident that when using accuracy as the scoring metric, higher alpha values yield better results. Conversely, in the case of precision, lower alpha values correspond to better precision. However, based from the classification reports, alpha value of 1 seems to be the optimal choice to have a balance accuracy, precision, recall and f1-score.

# %%
# Use the model with 1 as alpha value
y_pred = mnb_vc_model.predict(x_test_vect)

# Create a confusion matrix
class_labels = ['Negative', 'Neutral', 'Positive']
cm = confusion_matrix(y_test, y_pred)
cm_matrix = pd.DataFrame(data=cm, columns=class_labels, index=class_labels)

sb.heatmap(cm_matrix, cmap='Greens', annot=True, fmt='d', annot_kws={"size": 12})

plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
plt.xlabel('Actual Class', fontsize=14)
plt.ylabel('Predicted Class', fontsize=14)
# Out:
# Text(43.25, 0.5, 'Predicted Class')

# %%
# Binarize the labels for multiclass ROC curve
y_test_bin = label_binarize(y_test, classes=[0, 1, 2])  # Replace [0, 1, 2] with your actual class labels

# Get the predicted probabilities for each class
probas_multinomial = mnb_vc_model.predict_proba(x_test_vect)

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()

n_classes = y_test_bin.shape[1]

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], probas_multinomial[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(8, 6))

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve for Multiclass')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# __Observation:__
# The ROC curve is a graphical representation of a model's ability to distinguish between different classes. It illustrates the balance between correctly identifying positive cases and correctly ruling out negative cases across different decision boundaries. In simple terms, a good ROC curve should hug the top-left corner, indicating high true positive rates and low false positive rates.
# - Class 0 (Positive Movie Review) has a high AUC of 0.88, indicating good performance.
# - Class 1 (Neutral Movie Review) has a lower AUC of 0.76, suggesting that the model is less effective at distinguishing neutral reviews.
# - Class 2 (Negative Movie Review) also has a high AUC of 0.88, similar to positive reviews.
# Overall, the model performs well for positive and negative movie reviews, but there is room for improvement in distinguishing neutral reviews.

# %% [markdown]
# ## Conclusion
# - The Movie Sentiment model exhibits a moderate level of overall performance. Further analysis and additional data pre-processing is necessary to refine the model and achieve better results.
# - The word cloud shows common occurrences of words such as "file," "movie,", "character" and "good" across all classes, posing challenges for precise class prediction in movie reviews. Additional data preprocessing, such as removal of common occuring nouns related to movie and handling word negations through POS tagging, is necessary for effective class separation. Alternatively, using a different model may enhance accuracy in classification, like LSTM (Long Short-Term Memory) or RNN (Recurrent Neural Network).

# %% [markdown]
# ## References
# - https://medium.com/analytics-vidhya/text-preprocessing-nlp-basics-430d54016048
# - https://towardsdatascience.com/how-to-preprocess-social-media-data-and-text-messages-b011efacf74
# - https://towardsdatascience.com/5-lesser-known-python-libraries-for-your-next-nlp-project-ff13fc652553
# - https://medium.com/coinmonks/remaking-of-shortened-sms-tweet-post-slangs-and-word-contraction-into-sentences-nlp-7bd1bbc6fcff
# - https://sunscrapers.com/blog/9-best-python-natural-language-processing-nlp/
# - https://towardsdatascience.com/stemming-vs-lemmatization-2daddabcb221
# - https://www.machinelearningplus.com/nlp/lemmatization-examples-python/#google_vignette
# - https://atilaycemsamiloglu.medium.com/what-is-lemmatization-2d7a87f42c55
# - https://support.prodi.gy/t/how-to-tell-spacy-not-to-split-any-intra-hyphen-words/1456
# - https://towardsdatascience.com/elegant-text-pre-processing-with-nltk-in-sklearn-pipeline-d6fe18b91eb8
# - https://python.plainenglish.io/optimize-your-spacy-ner-results-with-this-simple-change-e59937c411ab

# %% [markdown]
# ## Group 3 Members
# - Abhishek Natani
# - Auradee Castro
# - Bhumika Rajendra Babu
# - Miraj Sinya
# - Olivia Deguit
# - Rochan Mehta
# - Roger Mais
# - Varun Sharma
